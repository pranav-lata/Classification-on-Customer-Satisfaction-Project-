# %% [markdown]
# ## Binary Classification

# %%
import pandas as pd

# %%
df = pd.read_csv('cust_satisfaction.csv')
df.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
# 3                 3            2                          11
# 4                 4            3                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0

# %%
df['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64

# %%
#Y-Variable would be Satisfaction Column. We need to train a ML algo to predict Satisfaction

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  object
#  1   Customer Type               103904 non-null  object
#  2   Type of Travel              103904 non-null  object
#  3   Class                       103904 non-null  object
#  4   satisfaction                103904 non-null  object
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 9.5+ MB

# %%
#Removing Duplicate Record
df.duplicated().sum()
# Out:
# 172

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Removing Missing Values
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
#310 is a very small amount of data so we will remove it
df.dropna(inplace=True) #Each row will be deleted in which missing value is present

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
#Y has 2 classes for prediction so it is called binary classification

# %%
#Balancity of Data 
df['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58636
# satisfied                  44786
# Name: count, dtype: int64

# %%
#This dataset is a balanced dataset

# %%
df.head(2)
# Out:
#   Gender      Customer Type   Type of Travel     Class  \
# 0   Male     Loyal Customer  Personal Travel  Eco Plus
# 1   Male  disloyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0

# %%
df['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    71331
# Personal Travel    32091
# Name: count, dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# Business    49423
# Eco         46532
# Eco Plus     7467
# Name: count, dtype: int64

# %%
df['Inflight entertainment'].max()
# Out:
# 5

# %%
df['Inflight entertainment'].min()
# Out:
# 0

# %%
df['Baggage handling'].max()
# Out:
# 5

# %%
df['Baggage handling'].min()
# Out:
# 1

# %%
df['Cleanliness'].max()
# Out:
# 5

# %%
df['Cleanliness'].min()
# Out:
# 0

# %%
df2 = df[(df['Inflight entertainment']==5)&(df['Baggage handling']==5)&(df['Cleanliness']==5)]

# %%
df2
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 17        Male     Loyal Customer  Business travel  Business
# 36      Female  disloyal Customer  Business travel  Business
# 45        Male     Loyal Customer  Business travel  Business
# 56      Female     Loyal Customer  Business travel  Business
# 70      Female     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103838    Male     Loyal Customer  Business travel  Business
# 103847    Male     Loyal Customer  Business travel  Business
# 103853  Female     Loyal Customer  Business travel       Eco
# 103857    Male  disloyal Customer  Business travel       Eco
# 103886    Male  disloyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 17                    satisfied   41             2075                       5
# 36      neutral or dissatisfied   34              883                       5
# 45                    satisfied   29              529                       5
# 56                    satisfied   57             2496                       5
# 70                    satisfied   53             1506                       5
# ...                         ...  ...              ...                     ...
# 103838                satisfied   51             1723                       5
# 103847                satisfied   45             3727                       5
# 103853                satisfied   49              760                       5
# 103857  neutral or dissatisfied   26              370                       5
# 103886  neutral or dissatisfied   36             2556                       5
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 17                     5            5                           0
# 36                     5            5                           0
# 45                     5            5                           4
# 56                     5            5                           0
# 70                     5            5                           0
# ...                  ...          ...                         ...
# 103838                 5            5                          14
# 103847                 5            5                           0
# 103853                 5            5                           0
# 103857                 5            5                           0
# 103886                 5            5                           2
#
#         Arrival Delay in Minutes
# 17                          10.0
# 36                           0.0
# 45                           0.0
# 56                           5.0
# 70                           0.0
# ...                          ...
# 103838                       2.0
# 103847                       0.0
# 103853                      21.0
# 103857                       0.0
# 103886                      13.0
#
# [6729 rows x 12 columns]

# %%
df2.shape
# Out:
# (6729, 12)

# %%
#Dissatisfied
df3 = df2[df2['satisfaction'] == 'neutral or dissatisfied']
df3
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 36      Female  disloyal Customer  Business travel  Business
# 86      Female     Loyal Customer  Personal Travel  Eco Plus
# 87        Male     Loyal Customer  Personal Travel       Eco
# 249       Male  disloyal Customer  Business travel       Eco
# 261     Female     Loyal Customer  Personal Travel       Eco
# ...        ...                ...              ...       ...
# 103685    Male     Loyal Customer  Personal Travel       Eco
# 103773  Female  disloyal Customer  Business travel       Eco
# 103812  Female  disloyal Customer  Business travel  Business
# 103857    Male  disloyal Customer  Business travel       Eco
# 103886    Male  disloyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 36      neutral or dissatisfied   34              883                       5
# 86      neutral or dissatisfied   57              500                       5
# 87      neutral or dissatisfied   44              689                       5
# 249     neutral or dissatisfied   27              925                       5
# 261     neutral or dissatisfied   53              552                       5
# ...                         ...  ...              ...                     ...
# 103685  neutral or dissatisfied   42              372                       5
# 103773  neutral or dissatisfied   28              563                       5
# 103812  neutral or dissatisfied   28              814                       5
# 103857  neutral or dissatisfied   26              370                       5
# 103886  neutral or dissatisfied   36             2556                       5
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 36                     5            5                           0
# 86                     5            5                           0
# 87                     5            5                           0
# 249                    5            5                           4
# 261                    5            5                           0
# ...                  ...          ...                         ...
# 103685                 5            5                           0
# 103773                 5            5                           0
# 103812                 5            5                         212
# 103857                 5            5                           0
# 103886                 5            5                           2
#
#         Arrival Delay in Minutes
# 36                           0.0
# 86                           0.0
# 87                           0.0
# 249                          3.0
# 261                          0.0
# ...                          ...
# 103685                       5.0
# 103773                       6.0
# 103812                     212.0
# 103857                       0.0
# 103886                      13.0
#
# [1952 rows x 12 columns]

# %%
#Full rating Zero arrival and departure delay are 0 still dissatified
df4 = df3[(df3['Departure Delay in Minutes'] == 0)&(df['Arrival Delay in Minutes'] ==0)]
df4
# Out:
# C:\Users\Pranav\AppData\Local\Temp\ipykernel_14756\1341055788.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df4 = df3[(df3['Departure Delay in Minutes'] == 0)&(df['Arrival Delay in Minutes'] ==0)]
#         Gender      Customer Type   Type of Travel     Class  \
# 36      Female  disloyal Customer  Business travel  Business
# 86      Female     Loyal Customer  Personal Travel  Eco Plus
# 87        Male     Loyal Customer  Personal Travel       Eco
# 261     Female     Loyal Customer  Personal Travel       Eco
# 343     Female  disloyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103354    Male     Loyal Customer  Personal Travel       Eco
# 103484  Female     Loyal Customer  Personal Travel  Eco Plus
# 103486    Male  disloyal Customer  Business travel       Eco
# 103642  Female     Loyal Customer  Personal Travel       Eco
# 103857    Male  disloyal Customer  Business travel       Eco
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 36      neutral or dissatisfied   34              883                       5
# 86      neutral or dissatisfied   57              500                       5
# 87      neutral or dissatisfied   44              689                       5
# 261     neutral or dissatisfied   53              552                       5
# 343     neutral or dissatisfied   36              327                       5
# ...                         ...  ...              ...                     ...
# 103354  neutral or dissatisfied   59              696                       5
# 103484  neutral or dissatisfied   23              834                       5
# 103486  neutral or dissatisfied   24              101                       5
# 103642  neutral or dissatisfied   23              436                       5
# 103857  neutral or dissatisfied   26              370                       5
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 36                     5            5                           0
# 86                     5            5                           0
# 87                     5            5                           0
# 261                    5            5                           0
# 343                    5            5                           0
# ...                  ...          ...                         ...
# 103354                 5            5                           0
# 103484                 5            5                           0
# 103486                 5            5                           0
# 103642                 5            5                           0
# 103857                 5            5                           0
#
#         Arrival Delay in Minutes
# 36                           0.0
# 86                           0.0
# 87                           0.0
# 261                          0.0
# 343                          0.0
# ...                          ...
# 103354                       0.0
# 103484                       0.0
# 103486                       0.0
# 103642                       0.0
# 103857                       0.0
#
# [899 rows x 12 columns]

# %%
df2['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       5805
# disloyal Customer     924
# Name: count, dtype: int64

# %%
female = df[df['Gender']=='Female']
female
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 5       Female     Loyal Customer  Personal Travel       Eco
# 7       Female     Loyal Customer  Business travel  Business
# 8       Female     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103893  Female     Loyal Customer  Business travel  Business
# 103895  Female  disloyal Customer  Business travel       Eco
# 103897  Female     Loyal Customer  Business travel  Business
# 103899  Female  disloyal Customer  Business travel       Eco
# 103902  Female  disloyal Customer  Business travel       Eco
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 5       neutral or dissatisfied   26             1180                       1
# 7                     satisfied   52             2035                       5
# 8       neutral or dissatisfied   41              853                       1
# ...                         ...  ...              ...                     ...
# 103893  neutral or dissatisfied   58              296                       3
# 103895  neutral or dissatisfied   24             1055                       1
# 103897                satisfied   60             1599                       4
# 103899  neutral or dissatisfied   23              192                       2
# 103902  neutral or dissatisfied   22             1000                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 2                      4            5                           0
# 3                      3            2                          11
# 5                      4            1                           0
# 7                      5            4                           4
# 8                      1            2                           0
# ...                  ...          ...                         ...
# 103893                 3            1                           0
# 103895                 5            1                          13
# 103897                 4            4                           9
# 103899                 4            2                           3
# 103902                 1            1                           0
#
#         Arrival Delay in Minutes
# 2                            0.0
# 3                            9.0
# 5                            0.0
# 7                            0.0
# 8                            0.0
# ...                          ...
# 103893                      29.0
# 103895                      10.0
# 103897                       7.0
# 103899                       0.0
# 103902                       0.0
#
# [52500 rows x 12 columns]

# %%
female['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       42272
# disloyal Customer    10228
# Name: count, dtype: int64

# %%
df5 = female[female['satisfaction'] == 'satisfied']
df5
# Out:
#         Gender      Customer Type   Type of Travel     Class satisfaction  \
# 2       Female     Loyal Customer  Business travel  Business    satisfied
# 7       Female     Loyal Customer  Business travel  Business    satisfied
# 16      Female     Loyal Customer  Business travel  Business    satisfied
# 18      Female     Loyal Customer  Business travel  Business    satisfied
# 24      Female  disloyal Customer  Business travel       Eco    satisfied
# ...        ...                ...              ...       ...          ...
# 103881  Female     Loyal Customer  Business travel  Business    satisfied
# 103887  Female     Loyal Customer  Personal Travel       Eco    satisfied
# 103889  Female     Loyal Customer  Business travel  Business    satisfied
# 103890  Female     Loyal Customer  Business travel  Eco Plus    satisfied
# 103897  Female     Loyal Customer  Business travel  Business    satisfied
#
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 2        26             1142                       5                 4
# 7        52             2035                       5                 5
# 16       26             2123                       4                 4
# 18       45             2486                       5                 5
# 24       23              452                       1                 5
# ...     ...              ...                     ...               ...
# 103881   51              384                       4                 4
# 103887   51             1222                       3                 3
# 103889   43             3885                       3                 3
# 103890   56              550                       3                 3
# 103897   60             1599                       4                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 2                 5                           0                       0.0
# 7                 4                           4                       0.0
# 16                4                          49                      51.0
# 18                4                           7                       5.0
# 24                1                          54                      44.0
# ...             ...                         ...                       ...
# 103881            3                          54                      51.0
# 103887            4                           4                       0.0
# 103889            3                           0                       0.0
# 103890            3                           0                       0.0
# 103897            4                           9                       7.0
#
# [22415 rows x 12 columns]

# %%
df5['Baggage handling'].value_counts()
#1009 Female Passengers who are satisfied still they gave 1 star
# Out:
# Baggage handling
# 4    8983
# 5    8479
# 3    2284
# 2    1660
# 1    1009
# Name: count, dtype: int64

# %% [markdown]
# #### Data Conversion into numerical form

# %%
# df['Gender'] = df['Gender'].map({'Female':0,'Male':1})

# %%
# df['Customer Type'] = df['Customer Type'].map({'Loyal Customer':1,'disloyal Customer':0})

# %%
# df['Type of Travel'] = df['Type of Travel'].map({

# %%
#The above methods are very time taking for high no. of columns 
#So the below method is a shortcut method

# %%
df6 = pd.get_dummies(df,drop_first='if_binary').astype('int')
df6
#One hot encoding representation
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0        13              460                       5                 4
# 1        25              235                       1                 3
# 2        26             1142                       5                 4
# 3        25              562                       2                 3
# 4        61              214                       3                 4
# ...     ...              ...                     ...               ...
# 103899   23              192                       2                 4
# 103900   49             2347                       5                 5
# 103901   30             1995                       4                 4
# 103902   22             1000                       1                 1
# 103903   27             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                 5                          25                        18
# 1                 1                           1                         6
# 2                 5                           0                         0
# 3                 2                          11                         9
# 4                 3                           0                         0
# ...             ...                         ...                       ...
# 103899            2                           3                         0
# 103900            4                           0                         0
# 103901            4                           7                        14
# 103902            1                           0                         0
# 103903            1                           0                         0
#
#         Gender_Male  Customer Type_disloyal Customer  \
# 0                 1                                0
# 1                 1                                1
# 2                 0                                0
# 3                 0                                0
# 4                 1                                0
# ...             ...                              ...
# 103899            0                                1
# 103900            1                                0
# 103901            1                                1
# 103902            0                                1
# 103903            1                                0
#
#         Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 0                                    1          0               1
# 1                                    0          0               0
# 2                                    0          0               0
# 3                                    0          0               0
# 4                                    0          0               0
# ...                                ...        ...             ...
# 103899                               0          1               0
# 103900                               0          0               0
# 103901                               0          0               0
# 103902                               0          1               0
# 103903                               0          0               0
#
#         satisfaction_satisfied
# 0                            0
# 1                            0
# 2                            1
# 3                            0
# 4                            1
# ...                        ...
# 103899                       0
# 103900                       1
# 103901                       0
# 103902                       0
# 103903                       0
#
# [103422 rows x 13 columns]

# %%
df6.isnull().sum()
# Out:
# Age                                0
# Flight Distance                    0
# Inflight entertainment             0
# Baggage handling                   0
# Cleanliness                        0
# Departure Delay in Minutes         0
# Arrival Delay in Minutes           0
# Gender_Male                        0
# Customer Type_disloyal Customer    0
# Type of Travel_Personal Travel     0
# Class_Eco                          0
# Class_Eco Plus                     0
# satisfaction_satisfied             0
# dtype: int64

# %% [markdown]
# #### Convering the data into Dependent and Independent Variables (X & Y)

# %%
x = df6.drop('satisfaction_satisfied',axis=1)
y = df6[['satisfaction_satisfied']]

# %%
#Train Test Split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
#Model Training 
#Name of Algorithm for Logistic Regresion
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# C:\Users\Pranav\anaconda\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Pranav\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#Model Performance (Model Evaluation)
print("Training Score: ", round(lg.score(x_train,y_train)*100))
print("Testing Score: ", round(lg.score(x_test,y_test)*100))
# Out:
# Training Score:  78
# Testing Score:  78

# %%
#Model is not overfit and underfit
#Getting Predictions
predictions = lg.predict(x_test)

#Adding Prediction Column with Actual dataset
y_test['satisfaction_prediction'] = predictions
y_test.head(25)
# Out:
#         satisfaction_satisfied  satisfaction_prediction
# 91504                        0                        0
# 63238                        0                        0
# 12938                        0                        0
# 17514                        1                        1
# 50859                        0                        0
# 51670                        0                        0
# 10767                        0                        0
# 31628                        0                        1
# 66409                        0                        0
# 8637                         1                        1
# 18624                        1                        1
# 18807                        0                        0
# 86157                        1                        1
# 51656                        0                        0
# 71076                        1                        1
# 33705                        0                        0
# 71495                        0                        0
# 14259                        0                        0
# 70407                        1                        0
# 99862                        1                        1
# 103367                       0                        0
# 66879                        0                        0
# 55639                        0                        1
# 35568                        0                        0
# 86478                        0                        1

# %% [markdown]
# #### Evaluation of Model

# %%
#Confusion Matrix 
#True Positive -
#False Positive - 
#True Negative - 
#False Negative -

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test['satisfaction_satisfied'],y_test['satisfaction_prediction'])
matrix
# Out:
# array([[9291, 2553],
#        [1902, 6939]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(matrix,annot=True,fmt="d",cmap='coolwarm')
plt.title('Confusion Matrix')
plt.axis('off')
plt.show()

# %%
print("Training Score: ", round(lg.score(x_train,y_train)*100))
print("Testing Score: ", round(lg.score(x_test,y_test['satisfaction_satisfied'])*100))
# Out:
# Training Score:  78
# Testing Score:  78

# %%
#Checking Accuracy
accuracy = round((9204+7058)/(9204+7058+1842+2581),2)*100
accuracy
# Out:
# 79.0

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test['satisfaction_satisfied'],y_test['satisfaction_prediction']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.81     11844
#            1       0.73      0.78      0.76      8841
#
#     accuracy                           0.78     20685
#    macro avg       0.78      0.78      0.78     20685
# weighted avg       0.79      0.78      0.79     20685

# %%
#Interview Question 
#Formula of Metrics Evaluation (Precision, Accuraccy, recall, f1-score)

# %% [markdown]
# ### Using Decision Tree

# %%
x_train.shape
# Out:
# (82737, 12)

# %%
x_test.shape
# Out:
# (20685, 12)

# %%
y_train.shape
# Out:
# (82737, 1)

# %%
y_test.shape
# Out:
# (20685, 1)

# %%
#Model Training using Decision Trees
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)

#Model Performance (Model Evaluation)
print("Training Score: ", round(dt.score(x_train,y_train),2)*100)
print("Testing Score: ", round(dt.score(x_test,y_test),2)*100)
# Out:
# Training Score:  100.0
# Testing Score:  82.0

# %%
#Generate Classification Report, Confusion Matrix
#Predicions find, Saving the model

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(dt)
# Out:
# [Text(0.54992608435253, 0.9895833333333334, 'x[10] <= 0.5\ngini = 0.491\nsamples = 82737\nvalue = [46967, 35770]'),
#  Text(0.3206625890786463, 0.96875, 'x[2] <= 3.5\ngini = 0.464\nsamples = 45421\nvalue = [16587, 28834]'),
#  Text(0.21701535141574016, 0.9479166666666666, 'x[4] <= 4.5\ngini = 0.444\nsamples = 17846\nvalue = [11908, 5938]'),
#  Text(0.1534782303482974, 0.9270833333333334, 'x[4] <= 2.5\ngini = 0.413\nsamples = 16474\nvalue = [11678, 4796]'),
#  Text(0.06346034333830439, 0.90625, 'x[8] <= 0.5\ngini = 0.316\nsamples = 8248\nvalue = [6623, 1625]'),
#  Text(0.04907765753468528, 0.8854166666666666, 'x[3] <= 4.5\ngini = 0.22\nsamples = 5779\nvalue = [5051, 728]'),
#  Text(0.035662560427790896, 0.8645833333333334, 'x[6] <= 5.5\ngini = 0.191\nsamples = 5376\nvalue = [4801, 575]'),
#  Text(0.017888929164776, 0.84375, 'x[2] <= 1.5\ngini = 0.246\nsamples = 3084\nvalue = [2641, 443]'),
#  Text(0.005316296361427259, 0.8229166666666666, 'x[9] <= 0.5\ngini = 0.146\nsamples = 956\nvalue = [880, 76]'),
#  Text(0.0020987007147727377, 0.8020833333333334, 'x[1] <= 302.0\ngini = 0.098\nsamples = 678\nvalue = [643, 35]'),
#  Text(0.0010385323124648598, 0.78125, 'x[0] <= 37.5\ngini = 0.234\nsamples = 74\nvalue = [64, 10]'),
#  Text(0.0007912627142589409, 0.7604166666666666, 'x[0] <= 35.5\ngini = 0.355\nsamples = 26\nvalue = [20, 6]'),
#  Text(0.0005934470356942056, 0.7395833333333334, 'x[1] <= 298.5\ngini = 0.287\nsamples = 23\nvalue = [19, 4]'),
#  Text(0.000494539196411838, 0.71875, 'x[1] <= 242.0\ngini = 0.236\nsamples = 22\nvalue = [19, 3]'),
#  Text(0.0002967235178471028, 0.6979166666666666, 'x[3] <= 2.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.00019781567856473522, 0.6770833333333334, 'x[11] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(9.890783928236761e-05, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0002967235178471028, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.00039563135712947044, 0.6770833333333334, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.0006923548749765732, 0.6979166666666666, 'x[11] <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.0005934470356942056, 0.6770833333333334, 'x[3] <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.000494539196411838, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0006923548749765732, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0007912627142589409, 0.6770833333333334, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.0006923548749765732, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.000989078392823676, 0.7395833333333334, 'x[1] <= 198.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0008901705535413084, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0010879862321060436, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0012858019106707788, 0.7604166666666666, 'x[0] <= 50.5\ngini = 0.153\nsamples = 48\nvalue = [44, 4]'),
#  Text(0.0011868940713884112, 0.7395833333333334, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.0013847097499531465, 0.7395833333333334, 'x[0] <= 51.5\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(0.0012858019106707788, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0014836175892355141, 0.71875, 'x[7] <= 0.5\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.0011868940713884112, 0.6979166666666666, 'x[0] <= 53.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.0010879862321060436, 0.6770833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0012858019106707788, 0.6770833333333334, 'x[1] <= 258.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.0011868940713884112, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0013847097499531465, 0.65625, 'x[11] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0012858019106707788, 0.6354166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0014836175892355141, 0.6354166666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0017803411070826168, 0.6979166666666666, 'x[1] <= 146.0\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.0016814332678002492, 0.6770833333333334, 'x[1] <= 121.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.0015825254285178818, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0017803411070826168, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0018792489463649845, 0.6770833333333334, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.0031588691170806155, 0.78125, 'x[0] <= 25.5\ngini = 0.079\nsamples = 604\nvalue = [579, 25]'),
#  Text(0.0020770646249297195, 0.7604166666666666, 'x[6] <= 3.5\ngini = 0.026\nsamples = 153\nvalue = [151, 2]'),
#  Text(0.001978156785647352, 0.7395833333333334, 'gini = 0.0\nsamples = 141\nvalue = [141, 0]'),
#  Text(0.002175972464212087, 0.7395833333333334, 'x[5] <= 1.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.0020770646249297195, 0.71875, 'x[3] <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.001978156785647352, 0.6979166666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.002175972464212087, 0.6979166666666666, 'x[0] <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0020770646249297195, 0.6770833333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.002274880303494455, 0.6770833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.002274880303494455, 0.71875, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.004240673609231511, 0.7604166666666666, 'x[0] <= 37.5\ngini = 0.097\nsamples = 451\nvalue = [428, 23]'),
#  Text(0.0032886856561387227, 0.7395833333333334, 'x[11] <= 0.5\ngini = 0.154\nsamples = 179\nvalue = [164, 15]'),
#  Text(0.0028683273391886606, 0.71875, 'x[5] <= 0.5\ngini = 0.114\nsamples = 148\nvalue = [139, 9]'),
#  Text(0.002769419499906293, 0.6979166666666666, 'x[6] <= 2.5\ngini = 0.148\nsamples = 112\nvalue = [103, 9]'),
#  Text(0.00247269598205919, 0.6770833333333334, 'x[1] <= 2480.5\ngini = 0.126\nsamples = 104\nvalue = [97, 7]'),
#  Text(0.002175972464212087, 0.65625, 'x[1] <= 686.0\ngini = 0.062\nsamples = 62\nvalue = [60, 2]'),
#  Text(0.0020770646249297195, 0.6354166666666666, 'x[1] <= 636.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.001978156785647352, 0.6145833333333334, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.002175972464212087, 0.6145833333333334, 'x[3] <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0020770646249297195, 0.59375, 'x[1] <= 661.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.001978156785647352, 0.5729166666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.002175972464212087, 0.5729166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.002274880303494455, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.002274880303494455, 0.6354166666666666, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.002769419499906293, 0.65625, 'x[1] <= 2508.5\ngini = 0.21\nsamples = 42\nvalue = [37, 5]'),
#  Text(0.0026705116606239253, 0.6354166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0028683273391886606, 0.6354166666666666, 'x[1] <= 2873.0\ngini = 0.176\nsamples = 41\nvalue = [37, 4]'),
#  Text(0.0025716038213415577, 0.6145833333333334, 'x[1] <= 2622.5\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.00247269598205919, 0.59375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.0026705116606239253, 0.59375, 'x[1] <= 2666.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.0025716038213415577, 0.5729166666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.002769419499906293, 0.5729166666666666, 'x[1] <= 2803.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.0026705116606239253, 0.5520833333333334, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.0028683273391886606, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0031650508570357635, 0.6145833333333334, 'x[0] <= 27.0\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.003066143017753396, 0.59375, 'x[7] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.0029672351784710282, 0.5729166666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0031650508570357635, 0.5729166666666666, 'x[1] <= 3378.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.003066143017753396, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0032639586963181307, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0032639586963181307, 0.59375, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.003066143017753396, 0.6770833333333334, 'x[0] <= 34.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.0029672351784710282, 0.65625, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.0031650508570357635, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0029672351784710282, 0.6979166666666666, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]'),
#  Text(0.0037090439730887853, 0.71875, 'x[3] <= 2.5\ngini = 0.312\nsamples = 31\nvalue = [25, 6]'),
#  Text(0.0033628665356004984, 0.6979166666666666, 'x[7] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.0032639586963181307, 0.6770833333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.003461774374882866, 0.6770833333333334, 'x[3] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.0033628665356004984, 0.65625, 'x[1] <= 777.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0032639586963181307, 0.6354166666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.003461774374882866, 0.6354166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0035606822141652336, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.004055221410577072, 0.6979166666666666, 'x[5] <= 3.0\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.0038574057320123365, 0.6770833333333334, 'x[3] <= 3.5\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.003758497892729969, 0.65625, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.003956313571294704, 0.65625, 'x[0] <= 30.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.0038574057320123365, 0.6354166666666666, 'x[1] <= 843.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.003758497892729969, 0.6145833333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.003956313571294704, 0.6145833333333334, 'x[1] <= 954.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0038574057320123365, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.004055221410577072, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.004055221410577072, 0.6354166666666666, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.004253037089141807, 0.6770833333333334, 'x[1] <= 990.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.004154129249859439, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.004351944928424174, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.005192661562324299, 0.7395833333333334, 'x[7] <= 0.5\ngini = 0.057\nsamples = 272\nvalue = [264, 8]'),
#  Text(0.005093753723041931, 0.71875, 'x[1] <= 3192.5\ngini = 0.118\nsamples = 127\nvalue = [119, 8]'),
#  Text(0.004846484124836013, 0.6979166666666666, 'x[0] <= 76.5\ngini = 0.073\nsamples = 105\nvalue = [101, 4]'),
#  Text(0.004648668446271278, 0.6770833333333334, 'x[1] <= 1700.0\ngini = 0.058\nsamples = 101\nvalue = [98, 3]'),
#  Text(0.00454976060698891, 0.65625, 'gini = 0.0\nsamples = 47\nvalue = [47, 0]'),
#  Text(0.004747576285553645, 0.65625, 'x[1] <= 1736.5\ngini = 0.105\nsamples = 54\nvalue = [51, 3]'),
#  Text(0.004648668446271278, 0.6354166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.004846484124836013, 0.6354166666666666, 'x[0] <= 52.5\ngini = 0.073\nsamples = 53\nvalue = [51, 2]'),
#  Text(0.004747576285553645, 0.6145833333333334, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.00494539196411838, 0.6145833333333334, 'x[0] <= 53.5\ngini = 0.137\nsamples = 27\nvalue = [25, 2]'),
#  Text(0.004747576285553645, 0.59375, 'x[1] <= 2732.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.004648668446271278, 0.5729166666666666, 'x[1] <= 2422.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.00454976060698891, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.004747576285553645, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.004846484124836013, 0.5729166666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.005143207642683115, 0.59375, 'x[1] <= 2067.0\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.005044299803400748, 0.5729166666666666, 'x[1] <= 2019.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.00494539196411838, 0.5520833333333334, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.005143207642683115, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.005242115481965483, 0.5729166666666666, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.005044299803400748, 0.6770833333333334, 'x[5] <= 1.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.00494539196411838, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.005143207642683115, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.005341023321247851, 0.6979166666666666, 'x[1] <= 3213.5\ngini = 0.298\nsamples = 22\nvalue = [18, 4]'),
#  Text(0.005242115481965483, 0.6770833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.005439931160530218, 0.6770833333333334, 'x[0] <= 58.5\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.005341023321247851, 0.65625, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.005538838999812586, 0.65625, 'x[1] <= 3726.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.005439931160530218, 0.6354166666666666, 'x[1] <= 3428.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.005341023321247851, 0.6145833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.005538838999812586, 0.6145833333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.005637746839094953, 0.6354166666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.005291569401606667, 0.71875, 'gini = 0.0\nsamples = 145\nvalue = [145, 0]'),
#  Text(0.00853389200808178, 0.8020833333333334, 'x[1] <= 936.5\ngini = 0.251\nsamples = 278\nvalue = [237, 41]'),
#  Text(0.006843186130348808, 0.78125, 'x[1] <= 263.0\ngini = 0.188\nsamples = 181\nvalue = [162, 19]'),
#  Text(0.0065279173926362614, 0.7604166666666666, 'x[1] <= 258.0\ngini = 0.332\nsamples = 38\nvalue = [30, 8]'),
#  Text(0.006429009553353894, 0.7395833333333334, 'x[0] <= 61.5\ngini = 0.278\nsamples = 36\nvalue = [30, 6]'),
#  Text(0.006330101714071527, 0.71875, 'x[0] <= 40.5\ngini = 0.245\nsamples = 35\nvalue = [30, 5]'),
#  Text(0.006231193874789159, 0.6979166666666666, 'x[0] <= 39.0\ngini = 0.32\nsamples = 25\nvalue = [20, 5]'),
#  Text(0.006132286035506792, 0.6770833333333334, 'x[1] <= 134.5\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.0059344703569420565, 0.65625, 'x[7] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.005835562517659688, 0.6354166666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.006033378196224424, 0.6354166666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.006330101714071527, 0.65625, 'x[0] <= 12.0\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.006231193874789159, 0.6354166666666666, 'x[0] <= 10.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.006132286035506792, 0.6145833333333334, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.006330101714071527, 0.6145833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.006429009553353894, 0.6354166666666666, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.006330101714071527, 0.6770833333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.006429009553353894, 0.6979166666666666, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.0065279173926362614, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0066268252319186295, 0.7395833333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.007158454868061355, 0.7604166666666666, 'x[1] <= 388.5\ngini = 0.142\nsamples = 143\nvalue = [132, 11]'),
#  Text(0.007059547028778988, 0.7395833333333334, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(0.007257362707343723, 0.7395833333333334, 'x[1] <= 407.5\ngini = 0.188\nsamples = 105\nvalue = [94, 11]'),
#  Text(0.006725733071200997, 0.71875, 'x[0] <= 35.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.0066268252319186295, 0.6979166666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.006824640910483365, 0.6979166666666666, 'x[5] <= 9.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.006725733071200997, 0.6770833333333334, 'x[11] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.0066268252319186295, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.006824640910483365, 0.65625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.006923548749765732, 0.6770833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.007788992343486449, 0.71875, 'x[0] <= 13.5\ngini = 0.134\nsamples = 97\nvalue = [90, 7]'),
#  Text(0.0073191801068952025, 0.6979166666666666, 'x[0] <= 11.5\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.007121364428330467, 0.6770833333333334, 'x[5] <= 3.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.0070224565890481, 0.65625, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.007220272267612835, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.007516995785459938, 0.6770833333333334, 'x[3] <= 2.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.007418087946177571, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.007615903624742306, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.008258804580077696, 0.6979166666666666, 'x[7] <= 0.5\ngini = 0.094\nsamples = 81\nvalue = [77, 4]'),
#  Text(0.008011534981871776, 0.6770833333333334, 'x[3] <= 3.5\ngini = 0.175\nsamples = 31\nvalue = [28, 3]'),
#  Text(0.007813719303307041, 0.65625, 'x[1] <= 508.0\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.007714811464024673, 0.6354166666666666, 'x[1] <= 486.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.007615903624742306, 0.6145833333333334, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.007813719303307041, 0.6145833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.007912627142589407, 0.6354166666666666, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.008209350660436512, 0.65625, 'x[0] <= 42.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.008110442821154144, 0.6354166666666666, 'x[1] <= 656.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.008011534981871776, 0.6145833333333334, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.008209350660436512, 0.6145833333333334, 'x[1] <= 682.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.008110442821154144, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.008308258499718878, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.008308258499718878, 0.6354166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.008506074178283614, 0.6770833333333334, 'x[1] <= 729.5\ngini = 0.039\nsamples = 50\nvalue = [49, 1]'),
#  Text(0.008407166339001246, 0.65625, 'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(0.008604982017565982, 0.65625, 'x[3] <= 2.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.008506074178283614, 0.6354166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.008703889856848349, 0.6354166666666666, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.010224597885814752, 0.78125, 'x[1] <= 1235.0\ngini = 0.351\nsamples = 97\nvalue = [75, 22]'),
#  Text(0.009420971691645514, 0.7604166666666666, 'x[5] <= 6.0\ngini = 0.459\nsamples = 42\nvalue = [27, 15]'),
#  Text(0.009148975133619003, 0.7395833333333334, 'x[0] <= 14.5\ngini = 0.418\nsamples = 37\nvalue = [26, 11]'),
#  Text(0.008901705535413085, 0.71875, 'x[5] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.008802797696130717, 0.6979166666666666, 'x[0] <= 13.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.008703889856848349, 0.6770833333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.008901705535413085, 0.6770833333333334, 'x[1] <= 1072.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.008802797696130717, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.009000613374695453, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.009000613374695453, 0.6979166666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.009396244731824922, 0.71875, 'x[1] <= 945.5\ngini = 0.358\nsamples = 30\nvalue = [23, 7]'),
#  Text(0.009198429053260187, 0.6979166666666666, 'x[3] <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.00909952121397782, 0.6770833333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.009297336892542555, 0.6770833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.009594060410389658, 0.6979166666666666, 'x[1] <= 1206.5\ngini = 0.302\nsamples = 27\nvalue = [22, 5]'),
#  Text(0.00949515257110729, 0.6770833333333334, 'x[7] <= 0.5\ngini = 0.26\nsamples = 26\nvalue = [22, 4]'),
#  Text(0.009396244731824922, 0.65625, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.009594060410389658, 0.65625, 'x[0] <= 25.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.00949515257110729, 0.6354166666666666, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.009692968249672026, 0.6354166666666666, 'x[0] <= 35.5\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.009594060410389658, 0.6145833333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.009791876088954392, 0.6145833333333334, 'x[0] <= 50.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.009692968249672026, 0.59375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.00989078392823676, 0.59375, 'x[0] <= 59.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.009791876088954392, 0.5729166666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.009989691767519128, 0.5729166666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.009692968249672026, 0.6770833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.009692968249672026, 0.7395833333333334, 'x[5] <= 17.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.009594060410389658, 0.71875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.009791876088954392, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.011028224079983988, 0.7604166666666666, 'x[1] <= 2601.0\ngini = 0.222\nsamples = 55\nvalue = [48, 7]'),
#  Text(0.01092931624070162, 0.7395833333333334, 'x[1] <= 2447.0\ngini = 0.198\nsamples = 54\nvalue = [48, 6]'),
#  Text(0.010830408401419253, 0.71875, 'x[1] <= 2315.0\ngini = 0.245\nsamples = 42\nvalue = [36, 6]'),
#  Text(0.010731500562136885, 0.6979166666666666, 'x[0] <= 28.0\ngini = 0.142\nsamples = 39\nvalue = [36, 3]'),
#  Text(0.010385323124648599, 0.6770833333333334, 'x[0] <= 26.0\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.010187507446083863, 0.65625, 'x[11] <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.010088599606801496, 0.6354166666666666, 'x[0] <= 13.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.009989691767519128, 0.6145833333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.010187507446083863, 0.6145833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01028641528536623, 0.6354166666666666, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.010583138803213333, 0.65625, 'x[3] <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.010484230963930965, 0.6354166666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.010682046642495701, 0.6354166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.011077677999625172, 0.6770833333333334, 'x[3] <= 1.5\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(0.010978770160342804, 0.65625, 'x[7] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.010879862321060436, 0.6354166666666666, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.011077677999625172, 0.6354166666666666, 'x[4] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.010978770160342804, 0.6145833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01117658583890754, 0.6145833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.01117658583890754, 0.65625, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.01092931624070162, 0.6979166666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.011028224079983988, 0.71875, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.011127131919266356, 0.7395833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.030461561968124738, 0.8229166666666666, 'x[0] <= 46.5\ngini = 0.285\nsamples = 2128\nvalue = [1761, 367]'),
#  Text(0.022652744591422757, 0.8020833333333334, 'x[1] <= 2198.5\ngini = 0.316\nsamples = 1399\nvalue = [1124, 275]'),
#  Text(0.016046734437009352, 0.78125, 'x[3] <= 1.5\ngini = 0.275\nsamples = 964\nvalue = [805, 159]'),
#  Text(0.011918394633525297, 0.7604166666666666, 'x[9] <= 0.5\ngini = 0.43\nsamples = 48\nvalue = [33, 15]'),
#  Text(0.011473309356754642, 0.7395833333333334, 'x[11] <= 0.5\ngini = 0.495\nsamples = 29\nvalue = [16, 13]'),
#  Text(0.011275493678189906, 0.71875, 'x[1] <= 583.5\ngini = 0.388\nsamples = 19\nvalue = [14, 5]'),
#  Text(0.01117658583890754, 0.6979166666666666, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.011374401517472274, 0.6979166666666666, 'x[1] <= 706.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.011275493678189906, 0.6770833333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.011473309356754642, 0.6770833333333334, 'x[5] <= 8.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.011374401517472274, 0.65625, 'x[0] <= 31.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.011275493678189906, 0.6354166666666666, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.011473309356754642, 0.6354166666666666, 'x[1] <= 1581.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.011374401517472274, 0.6145833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01157221719603701, 0.6145833333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01157221719603701, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.011671125035319377, 0.71875, 'x[1] <= 173.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.01157221719603701, 0.6979166666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.011770032874601745, 0.6979166666666666, 'x[1] <= 1734.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.011671125035319377, 0.6770833333333334, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.011868940713884113, 0.6770833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.01236347991029595, 0.7395833333333334, 'x[11] <= 0.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.012264572071013584, 0.71875, 'x[0] <= 24.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.012165664231731215, 0.6979166666666666, 'x[7] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.012066756392448847, 0.6770833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.012264572071013584, 0.6770833333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.01236347991029595, 0.6979166666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.012462387749578318, 0.71875, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.020175074240493408, 0.7604166666666666, 'x[11] <= 0.5\ngini = 0.265\nsamples = 916\nvalue = [772, 144]'),
#  Text(0.017017171020280785, 0.7395833333333334, 'x[3] <= 3.5\ngini = 0.298\nsamples = 621\nvalue = [508, 113]'),
#  Text(0.014441317252720064, 0.71875, 'x[0] <= 29.5\ngini = 0.248\nsamples = 468\nvalue = [400, 68]'),
#  Text(0.012561295588860686, 0.6979166666666666, 'x[1] <= 458.5\ngini = 0.143\nsamples = 129\nvalue = [119, 10]'),
#  Text(0.012462387749578318, 0.6770833333333334, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.012660203428143054, 0.6770833333333334, 'x[1] <= 483.0\ngini = 0.172\nsamples = 105\nvalue = [95, 10]'),
#  Text(0.012561295588860686, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01275911126742542, 0.65625, 'x[1] <= 1476.5\ngini = 0.158\nsamples = 104\nvalue = [95, 9]'),
#  Text(0.012258390331058435, 0.6354166666666666, 'x[1] <= 1143.5\ngini = 0.226\nsamples = 54\nvalue = [47, 7]'),
#  Text(0.01185039549401867, 0.6145833333333334, 'x[0] <= 10.5\ngini = 0.159\nsamples = 46\nvalue = [42, 4]'),
#  Text(0.011578398935992157, 0.59375, 'x[0] <= 9.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.011479491096709791, 0.5729166666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.011677306775274525, 0.5729166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01212239205204518, 0.59375, 'x[1] <= 527.5\ngini = 0.133\nsamples = 42\nvalue = [39, 3]'),
#  Text(0.01187512245383926, 0.5729166666666666, 'x[1] <= 524.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.011776214614556893, 0.5520833333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.011974030293121628, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.012369661650251098, 0.5729166666666666, 'x[0] <= 28.5\ngini = 0.1\nsamples = 38\nvalue = [36, 2]'),
#  Text(0.012171845971686364, 0.5520833333333334, 'x[3] <= 2.5\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(0.012072938132403996, 0.53125, 'x[0] <= 22.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.011974030293121628, 0.5104166666666666, 'x[7] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.01187512245383926, 0.4895833333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.012072938132403996, 0.4895833333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.012171845971686364, 0.5104166666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.01227075381096873, 0.53125, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.012567477328815834, 0.5520833333333334, 'x[1] <= 721.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.012468569489533466, 0.53125, 'x[1] <= 671.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.012369661650251098, 0.5104166666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.012567477328815834, 0.5104166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0126663851680982, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0126663851680982, 0.6145833333333334, 'x[1] <= 1295.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.012567477328815834, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.012765293007380569, 0.59375, 'x[5] <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.0126663851680982, 0.5729166666666666, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.012864200846662937, 0.5729166666666666, 'x[7] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.012765293007380569, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.012963108685945303, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.013259832203792407, 0.6354166666666666, 'x[1] <= 2090.0\ngini = 0.077\nsamples = 50\nvalue = [48, 2]'),
#  Text(0.013062016525227671, 0.6145833333333334, 'x[1] <= 1870.5\ngini = 0.043\nsamples = 46\nvalue = [45, 1]'),
#  Text(0.012963108685945303, 0.59375, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.01316092436451004, 0.59375, 'x[1] <= 1881.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.013062016525227671, 0.5729166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.013259832203792407, 0.5729166666666666, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.013457647882357142, 0.6145833333333334, 'x[1] <= 2115.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.013358740043074774, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01355655572163951, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.016321338916579442, 0.6979166666666666, 'x[1] <= 109.5\ngini = 0.284\nsamples = 339\nvalue = [281, 58]'),
#  Text(0.016123523238014706, 0.6770833333333334, 'x[3] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.016024615398732338, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.016222431077297074, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.016519154595144178, 0.6770833333333334, 'x[1] <= 2124.0\ngini = 0.278\nsamples = 336\nvalue = [280, 56]'),
#  Text(0.01642024675586181, 0.65625, 'x[1] <= 2119.0\ngini = 0.289\nsamples = 319\nvalue = [263, 56]'),
#  Text(0.016321338916579442, 0.6354166666666666, 'x[0] <= 39.5\ngini = 0.286\nsamples = 318\nvalue = [263, 55]'),
#  Text(0.014536361504530464, 0.6145833333333334, 'x[1] <= 779.5\ngini = 0.32\nsamples = 185\nvalue = [148, 37]'),
#  Text(0.013754371400204244, 0.59375, 'x[1] <= 439.0\ngini = 0.23\nsamples = 83\nvalue = [72, 11]'),
#  Text(0.013507101801998326, 0.5729166666666666, 'x[5] <= 5.5\ngini = 0.315\nsamples = 51\nvalue = [41, 10]'),
#  Text(0.013309286123433592, 0.5520833333333334, 'x[0] <= 30.5\ngini = 0.278\nsamples = 48\nvalue = [40, 8]'),
#  Text(0.013210378284151223, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.013408193962715958, 0.53125, 'x[1] <= 428.5\ngini = 0.254\nsamples = 47\nvalue = [40, 7]'),
#  Text(0.013309286123433592, 0.5104166666666666, 'x[9] <= 0.5\ngini = 0.227\nsamples = 46\nvalue = [40, 6]'),
#  Text(0.013210378284151223, 0.4895833333333333, 'x[6] <= 1.5\ngini = 0.198\nsamples = 45\nvalue = [40, 5]'),
#  Text(0.013012562605586487, 0.46875, 'x[3] <= 2.5\ngini = 0.139\nsamples = 40\nvalue = [37, 3]'),
#  Text(0.012913654766304121, 0.4479166666666667, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.013111470444868855, 0.4479166666666667, 'x[0] <= 38.5\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.012864200846662937, 0.4270833333333333, 'x[0] <= 31.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.0126663851680982, 0.40625, 'x[1] <= 317.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.012567477328815834, 0.3854166666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.012765293007380569, 0.3854166666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.013062016525227671, 0.40625, 'x[1] <= 375.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.012963108685945303, 0.3854166666666667, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.01316092436451004, 0.3854166666666667, 'x[1] <= 391.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.013062016525227671, 0.3645833333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.013259832203792407, 0.3645833333333333, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.013358740043074774, 0.4270833333333333, 'x[1] <= 266.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.013259832203792407, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.013457647882357142, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.013408193962715958, 0.46875, 'x[6] <= 3.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.013309286123433592, 0.4479166666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.013507101801998326, 0.4479166666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.013408193962715958, 0.4895833333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.013507101801998326, 0.5104166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01370491748056306, 0.5520833333333334, 'x[1] <= 259.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.013606009641280694, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.013803825319845428, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.014001640998410165, 0.5729166666666666, 'x[7] <= 0.5\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(0.013902733159127796, 0.5520833333333334, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.014100548837692531, 0.5520833333333334, 'x[1] <= 544.0\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.014001640998410165, 0.53125, 'x[1] <= 537.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.013902733159127796, 0.5104166666666666, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.014100548837692531, 0.5104166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.014199456676974899, 0.53125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.015318351608856683, 0.59375, 'x[1] <= 867.0\ngini = 0.38\nsamples = 102\nvalue = [76, 26]'),
#  Text(0.01459508803410437, 0.5729166666666666, 'x[0] <= 38.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.014496180194822001, 0.5520833333333334, 'x[9] <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.014397272355539635, 0.53125, 'x[1] <= 839.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.014298364516257267, 0.5104166666666666, 'x[5] <= 5.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.014199456676974899, 0.4895833333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.014397272355539635, 0.4895833333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.014496180194822001, 0.5104166666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.01459508803410437, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.014693995873386738, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.016041615183608995, 0.5729166666666666, 'x[1] <= 2076.0\ngini = 0.347\nsamples = 94\nvalue = [73, 21]'),
#  Text(0.015559439467107453, 0.5520833333333334, 'x[3] <= 2.5\ngini = 0.333\nsamples = 90\nvalue = [71, 19]'),
#  Text(0.014891811551951472, 0.53125, 'x[1] <= 1044.5\ngini = 0.411\nsamples = 38\nvalue = [27, 11]'),
#  Text(0.014693995873386738, 0.5104166666666666, 'x[0] <= 37.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.01459508803410437, 0.4895833333333333, 'x[1] <= 997.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.014496180194822001, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.014693995873386738, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.014792903712669106, 0.4895833333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.015089627230516208, 0.5104166666666666, 'x[5] <= 4.5\ngini = 0.342\nsamples = 32\nvalue = [25, 7]'),
#  Text(0.01499071939123384, 0.4895833333333333, 'x[5] <= 2.0\ngini = 0.375\nsamples = 28\nvalue = [21, 7]'),
#  Text(0.014891811551951472, 0.46875, 'x[6] <= 2.5\ngini = 0.346\nsamples = 27\nvalue = [21, 6]'),
#  Text(0.014792903712669106, 0.4479166666666667, 'x[0] <= 33.5\ngini = 0.311\nsamples = 26\nvalue = [21, 5]'),
#  Text(0.014545634114463185, 0.4270833333333333, 'x[1] <= 1602.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.014446726275180817, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.014644541953745554, 0.40625, 'x[6] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.014545634114463185, 0.3854166666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.014743449793027922, 0.3854166666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015040173310875024, 0.4270833333333333, 'x[7] <= 0.5\ngini = 0.236\nsamples = 22\nvalue = [19, 3]'),
#  Text(0.014941265471592656, 0.40625, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.015139081150157392, 0.40625, 'x[1] <= 1636.0\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.014941265471592656, 0.3854166666666667, 'x[1] <= 1234.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.014842357632310288, 0.3645833333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.015040173310875024, 0.3645833333333333, 'x[0] <= 35.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.014941265471592656, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015139081150157392, 0.34375, 'x[1] <= 1561.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.015040173310875024, 0.3229166666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.015237988989439758, 0.3229166666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015336896828722127, 0.3854166666666667, 'x[0] <= 36.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.015237988989439758, 0.3645833333333333, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.015435804668004495, 0.3645833333333333, 'x[0] <= 37.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.015336896828722127, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015534712507286861, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01499071939123384, 0.4479166666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015089627230516208, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015188535069798574, 0.4895833333333333, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.016227067382263434, 0.53125, 'x[1] <= 1789.5\ngini = 0.26\nsamples = 52\nvalue = [44, 8]'),
#  Text(0.016128159542981066, 0.5104166666666666, 'x[1] <= 1766.5\ngini = 0.303\nsamples = 43\nvalue = [35, 8]'),
#  Text(0.0160292517036987, 0.4895833333333333, 'x[0] <= 33.5\ngini = 0.278\nsamples = 42\nvalue = [35, 7]'),
#  Text(0.015534712507286861, 0.46875, 'x[1] <= 1539.5\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.015336896828722127, 0.4479166666666667, 'x[2] <= 2.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.015237988989439758, 0.4270833333333333, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.015435804668004495, 0.4270833333333333, 'x[1] <= 904.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.015336896828722127, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.015534712507286861, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015732528185851597, 0.4479166666666667, 'x[1] <= 1614.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.01563362034656923, 0.4270833333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.015831436025133965, 0.4270833333333333, 'x[1] <= 1677.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.015732528185851597, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.015930343864416333, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.016523790900110538, 0.46875, 'x[5] <= 17.5\ngini = 0.18\nsamples = 30\nvalue = [27, 3]'),
#  Text(0.016325975221545802, 0.4479166666666667, 'x[0] <= 36.5\ngini = 0.137\nsamples = 27\nvalue = [25, 2]'),
#  Text(0.016227067382263434, 0.4270833333333333, 'x[0] <= 35.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.016128159542981066, 0.40625, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.016325975221545802, 0.40625, 'x[1] <= 1310.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.016227067382263434, 0.3854166666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.01642488306082817, 0.3854166666666667, 'x[1] <= 1535.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.016325975221545802, 0.3645833333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.016523790900110538, 0.3645833333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.01642488306082817, 0.4270833333333333, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.016721606578675274, 0.4479166666666667, 'x[5] <= 19.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.016622698739392906, 0.4270833333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01682051441795764, 0.4270833333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.016227067382263434, 0.4895833333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.016325975221545802, 0.5104166666666666, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.016523790900110538, 0.5520833333333334, 'x[1] <= 2089.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.01642488306082817, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.016622698739392906, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01810631632862842, 0.6145833333333334, 'x[1] <= 637.5\ngini = 0.234\nsamples = 133\nvalue = [115, 18]'),
#  Text(0.017413961453651847, 0.59375, 'x[1] <= 590.0\ngini = 0.387\nsamples = 42\nvalue = [31, 11]'),
#  Text(0.01731505361436948, 0.5729166666666666, 'x[1] <= 230.5\ngini = 0.349\nsamples = 40\nvalue = [31, 9]'),
#  Text(0.017117237935804743, 0.5520833333333334, 'x[0] <= 43.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.017018330096522375, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.01721614577508711, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.017512869292934215, 0.5520833333333334, 'x[5] <= 0.5\ngini = 0.307\nsamples = 37\nvalue = [30, 7]'),
#  Text(0.017413961453651847, 0.53125, 'x[0] <= 43.5\ngini = 0.375\nsamples = 28\nvalue = [21, 7]'),
#  Text(0.017018330096522375, 0.5104166666666666, 'x[1] <= 299.0\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.01682051441795764, 0.4895833333333333, 'x[1] <= 274.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.016721606578675274, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.016919422257240007, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01721614577508711, 0.4895833333333333, 'x[4] <= 1.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.017117237935804743, 0.46875, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.01731505361436948, 0.46875, 'x[7] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.01721614577508711, 0.4479166666666667, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.017413961453651847, 0.4479166666666667, 'x[3] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.01731505361436948, 0.4270833333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.017512869292934215, 0.4270833333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.017809592810781316, 0.5104166666666666, 'x[1] <= 436.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.01761177713221658, 0.4895833333333333, 'x[1] <= 296.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.017512869292934215, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.017710684971498948, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.018007408489346052, 0.4895833333333333, 'x[1] <= 497.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.017908500650063684, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.01810631632862842, 0.46875, 'x[2] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.018007408489346052, 0.4479166666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.01820522416791079, 0.4479166666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.01761177713221658, 0.53125, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.017512869292934215, 0.5729166666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.018798671203604993, 0.59375, 'x[6] <= 2.5\ngini = 0.142\nsamples = 91\nvalue = [84, 7]'),
#  Text(0.018600855525040257, 0.5729166666666666, 'x[1] <= 1422.0\ngini = 0.093\nsamples = 82\nvalue = [78, 4]'),
#  Text(0.01850194768575789, 0.5520833333333334, 'x[1] <= 1391.5\ngini = 0.208\nsamples = 34\nvalue = [30, 4]'),
#  Text(0.01840303984647552, 0.53125, 'x[1] <= 1001.0\ngini = 0.117\nsamples = 32\nvalue = [30, 2]'),
#  Text(0.018304132007193153, 0.5104166666666666, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.01850194768575789, 0.5104166666666666, 'x[1] <= 1058.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.01840303984647552, 0.4895833333333333, 'x[4] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.018304132007193153, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.01850194768575789, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.018600855525040257, 0.4895833333333333, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.018600855525040257, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.018699763364322625, 0.5520833333333334, 'gini = 0.0\nsamples = 48\nvalue = [48, 0]'),
#  Text(0.01899648688216973, 0.5729166666666666, 'x[2] <= 2.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
# ...
#  Text(0.030420342319283186, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.030618157997847922, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.030618157997847922, 0.6354166666666666, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.03246649824443717, 0.65625, 'x[1] <= 3687.0\ngini = 0.422\nsamples = 149\nvalue = [104, 45]'),
#  Text(0.03171850770986426, 0.6354166666666666, 'x[1] <= 3259.5\ngini = 0.395\nsamples = 129\nvalue = [94, 35]'),
#  Text(0.03111269719425976, 0.6145833333333334, 'x[1] <= 3154.0\ngini = 0.436\nsamples = 84\nvalue = [57, 27]'),
#  Text(0.030815973676412655, 0.59375, 'x[0] <= 22.5\ngini = 0.416\nsamples = 78\nvalue = [55, 23]'),
#  Text(0.03071706583713029, 0.5729166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.030914881515695023, 0.5729166666666666, 'x[0] <= 27.0\ngini = 0.408\nsamples = 77\nvalue = [55, 22]'),
#  Text(0.030815973676412655, 0.5520833333333334, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.03101378935497739, 0.5520833333333334, 'x[1] <= 2484.5\ngini = 0.434\nsamples = 69\nvalue = [47, 22]'),
#  Text(0.030914881515695023, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03111269719425976, 0.53125, 'x[0] <= 29.5\ngini = 0.448\nsamples = 65\nvalue = [43, 22]'),
#  Text(0.030692338877309697, 0.5104166666666666, 'x[5] <= 4.0\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.03059343103802733, 0.4895833333333333, 'x[1] <= 2845.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.03049452319874496, 0.46875, 'x[1] <= 2660.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.030395615359462596, 0.4479166666666667, 'x[1] <= 2518.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.030296707520180228, 0.4270833333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03049452319874496, 0.4270833333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03059343103802733, 0.4479166666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.030692338877309697, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.030791246716592065, 0.4895833333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03153305551120982, 0.5104166666666666, 'x[1] <= 2802.0\ngini = 0.423\nsamples = 56\nvalue = [39, 17]'),
#  Text(0.031137424154080353, 0.4895833333333333, 'x[3] <= 3.5\ngini = 0.48\nsamples = 30\nvalue = [18, 12]'),
#  Text(0.031038516314797985, 0.46875, 'x[1] <= 2721.5\ngini = 0.499\nsamples = 25\nvalue = [13, 12]'),
#  Text(0.030791246716592065, 0.4479166666666667, 'x[1] <= 2674.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.030692338877309697, 0.4270833333333333, 'x[1] <= 2641.0\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.03049452319874496, 0.40625, 'x[3] <= 2.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.030395615359462596, 0.3854166666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03059343103802733, 0.3854166666666667, 'x[1] <= 2516.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.03049452319874496, 0.3645833333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.030692338877309697, 0.3645833333333333, 'x[0] <= 39.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.03059343103802733, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.030791246716592065, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.030890154555874433, 0.40625, 'x[4] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.030791246716592065, 0.3854166666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.0309890623951568, 0.3854166666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.030890154555874433, 0.4270833333333333, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.031285785913003905, 0.4479166666666667, 'x[0] <= 43.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.031186878073721534, 0.4270833333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.03138469375228627, 0.4270833333333333, 'x[2] <= 2.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.031285785913003905, 0.40625, 'x[5] <= 5.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.031186878073721534, 0.3854166666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03138469375228627, 0.3854166666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03148360159156864, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.031236331993362718, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.031928686868339294, 0.4895833333333333, 'x[1] <= 3023.5\ngini = 0.311\nsamples = 26\nvalue = [21, 5]'),
#  Text(0.031582509430851, 0.46875, 'x[0] <= 39.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.03148360159156864, 0.4479166666666667, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.03168141727013337, 0.4479166666666667, 'x[0] <= 42.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.031582509430851, 0.4270833333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03178032510941574, 0.4270833333333333, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.03227486430582758, 0.46875, 'x[0] <= 37.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.03207704862726284, 0.4479166666666667, 'x[1] <= 3068.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.031978140787980475, 0.4270833333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03217595646654521, 0.4270833333333333, 'x[1] <= 3081.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03207704862726284, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03227486430582758, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.032472679984392315, 0.4479166666666667, 'x[4] <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.03237377214510995, 0.4270833333333333, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03257158782367468, 0.4270833333333333, 'x[1] <= 3104.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.032472679984392315, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03267049566295705, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03140942071210686, 0.59375, 'x[3] <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.03131051287282449, 0.5729166666666666, 'x[0] <= 39.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.031211605033542127, 0.5520833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03140942071210686, 0.5520833333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03150832855138923, 0.5729166666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.03232431822546876, 0.6145833333333334, 'x[0] <= 45.5\ngini = 0.292\nsamples = 45\nvalue = [37, 8]'),
#  Text(0.0322254103861864, 0.59375, 'x[0] <= 25.5\ngini = 0.24\nsamples = 43\nvalue = [37, 6]'),
#  Text(0.03202759470762166, 0.5729166666666666, 'x[1] <= 3520.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.031928686868339294, 0.5520833333333334, 'x[1] <= 3376.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.031829779029056926, 0.53125, 'x[3] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03173087118977456, 0.5104166666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.031928686868339294, 0.5104166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03202759470762166, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.03212650254690403, 0.5520833333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03242322606475113, 0.5729166666666666, 'x[3] <= 2.5\ngini = 0.153\nsamples = 36\nvalue = [33, 3]'),
#  Text(0.03232431822546876, 0.5520833333333334, 'x[0] <= 37.0\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.0322254103861864, 0.53125, 'x[1] <= 3404.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.03212650254690403, 0.5104166666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03232431822546876, 0.5104166666666666, 'x[1] <= 3542.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.0322254103861864, 0.4895833333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.03242322606475113, 0.4895833333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03242322606475113, 0.53125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.032522133904033496, 0.5520833333333334, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.03242322606475113, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03321448877901007, 0.6354166666666666, 'x[3] <= 3.5\ngini = 0.5\nsamples = 20\nvalue = [10, 10]'),
#  Text(0.033115580939727704, 0.6145833333333334, 'x[4] <= 1.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.033016673100445336, 0.59375, 'x[0] <= 42.0\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.0328188574218806, 0.5729166666666666, 'x[0] <= 37.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.03271994958259823, 0.5520833333333334, 'x[3] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.032621041743315864, 0.53125, 'x[0] <= 35.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.032522133904033496, 0.5104166666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03271994958259823, 0.5104166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0328188574218806, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03291776526116297, 0.5520833333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.03321448877901007, 0.5729166666666666, 'x[3] <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.033115580939727704, 0.5520833333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03331339661829244, 0.5520833333333334, 'x[1] <= 3796.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03321448877901007, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03341230445757481, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03321448877901007, 0.59375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.03331339661829244, 0.6145833333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.030956608260392274, 0.6979166666666666, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.031987413397913195, 0.7604166666666666, 'x[3] <= 3.5\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.031789597719348466, 0.7395833333333334, 'x[5] <= 13.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.0316906898800661, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.031888505558630834, 0.71875, 'x[1] <= 2613.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.031789597719348466, 0.6979166666666666, 'x[6] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0316906898800661, 0.6770833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.031888505558630834, 0.6770833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.031987413397913195, 0.6979166666666666, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03218522907647793, 0.7395833333333334, 'x[1] <= 3325.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.03208632123719556, 0.71875, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.0322841369157603, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03827037934482672, 0.8020833333333334, 'x[1] <= 420.5\ngini = 0.221\nsamples = 729\nvalue = [637, 92]'),
#  Text(0.035702639110957134, 0.78125, 'x[1] <= 418.0\ngini = 0.344\nsamples = 163\nvalue = [127, 36]'),
#  Text(0.035603731271674766, 0.7604166666666666, 'x[1] <= 95.0\ngini = 0.333\nsamples = 161\nvalue = [127, 34]'),
#  Text(0.0355048234323924, 0.7395833333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.035702639110957134, 0.7395833333333334, 'x[1] <= 402.0\ngini = 0.327\nsamples = 160\nvalue = [127, 33]'),
#  Text(0.035603731271674766, 0.71875, 'x[1] <= 395.5\ngini = 0.343\nsamples = 150\nvalue = [117, 33]'),
#  Text(0.0355048234323924, 0.6979166666666666, 'x[1] <= 369.5\ngini = 0.325\nsamples = 147\nvalue = [117, 30]'),
#  Text(0.03443229155017422, 0.6770833333333334, 'x[3] <= 1.5\ngini = 0.304\nsamples = 134\nvalue = [109, 25]'),
#  Text(0.033659574055780725, 0.65625, 'x[1] <= 181.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.03356066621649836, 0.6354166666666666, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.03375848189506309, 0.6354166666666666, 'x[9] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.033659574055780725, 0.6145833333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.03385738973434546, 0.6145833333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03520500904456772, 0.65625, 'x[1] <= 271.0\ngini = 0.281\nsamples = 124\nvalue = [103, 21]'),
#  Text(0.034525017649501444, 0.6354166666666666, 'x[0] <= 74.5\ngini = 0.342\nsamples = 73\nvalue = [57, 16]'),
#  Text(0.0340552054129102, 0.6145833333333334, 'x[9] <= 0.5\ngini = 0.313\nsamples = 67\nvalue = [54, 13]'),
#  Text(0.03395629757362783, 0.59375, 'x[1] <= 122.5\ngini = 0.348\nsamples = 58\nvalue = [45, 13]'),
#  Text(0.033610120136139544, 0.5729166666666666, 'x[2] <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.033511212296857176, 0.5520833333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03370902797542191, 0.5520833333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.034302475011116114, 0.5729166666666666, 'x[11] <= 0.5\ngini = 0.306\nsamples = 53\nvalue = [43, 10]'),
#  Text(0.03390684365398664, 0.5520833333333334, 'x[1] <= 232.5\ngini = 0.198\nsamples = 36\nvalue = [32, 4]'),
#  Text(0.03370902797542191, 0.53125, 'x[0] <= 65.5\ngini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(0.033610120136139544, 0.5104166666666666, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.033807935814704274, 0.5104166666666666, 'x[1] <= 157.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03370902797542191, 0.4895833333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03390684365398664, 0.4895833333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03410465933255138, 0.53125, 'x[1] <= 235.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.03400575149326901, 0.5104166666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.034203567171833746, 0.5104166666666666, 'x[2] <= 2.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.03410465933255138, 0.4895833333333333, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.034302475011116114, 0.4895833333333333, 'x[6] <= 1.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.034203567171833746, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03440138285039848, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.034698106368245586, 0.5520833333333334, 'x[0] <= 51.0\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.03459919852896322, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.034797014207527954, 0.53125, 'x[1] <= 158.5\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.03459919852896322, 0.5104166666666666, 'x[2] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.03450029068968085, 0.4895833333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.034698106368245586, 0.4895833333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03499482988609269, 0.5104166666666666, 'x[1] <= 213.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.03489592204681032, 0.4895833333333333, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.03509373772537506, 0.4895833333333333, 'x[3] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03499482988609269, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03519264556465743, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.034154113252192565, 0.59375, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.03499482988609269, 0.6145833333333334, 'x[11] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.03489592204681032, 0.59375, 'x[4] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.034797014207527954, 0.5729166666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  ...]

# %% [markdown]
# ## Random Forest

# %%
#It is a combination of multiple decision trees

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rdf = RandomForestClassifier()

# %%
rdf.fit(x_train,y_train)
# Out:
# C:\Users\Pranav\AppData\Local\Temp\ipykernel_14756\1942363320.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rdf.fit(x_train,y_train)
# RandomForestClassifier()

# %%
print("Training Score: ", round(rdf.score(x_train,y_train),2)*100)
print("Testing Score: ", round(rdf.score(x_test,y_test),2)*100)
# Out:
# Training Score:  100.0
# Testing Score:  87.0

# %%
rdf2 = RandomForestClassifier(max_depth=8, min_samples_leaf=25, min_samples_split = 55)

# %%
rdf2.fit(x_train,y_train)
# Out:
# C:\Users\Pranav\AppData\Local\Temp\ipykernel_14756\2707250443.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rdf2.fit(x_train,y_train)
# RandomForestClassifier(max_depth=8, min_samples_leaf=25, min_samples_split=55)

# %%
print("Training Score: ", round(rdf.score(x_train,y_train),2)*100)
print("Testing Score: ", round(rdf.score(x_test,y_test),2)*100)

print("Training Score: ", round(rdf2.score(x_train,y_train),2)*100)
print("Testing Score: ", round(rdf2.score(x_test,y_test),2)*100)
# Out:
# Training Score:  100.0
# Testing Score:  87.0
# Training Score:  87.0
# Testing Score:  87.0
